# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Sahan\Documents\ds-project1\Data\DF.csv', encoding='latin1', low_memory=False)

# %%
df
# Out:
#        Unnamed: 0        Event.Id      Type Accident.Number        Date  \
# 0           24349  20001212X22389  Accident      CHI90LA059  1990-01-01
# 1           24350  20001212X22375  Accident      BFO90FA017  1990-01-02
# 2           24351  20001212X22482  Accident      NYC90LA044  1990-01-02
# 3           24352  20001212X22431  Accident     LAX90LA063B  1990-01-03
# 4           24353  20001212X22483  Accident      NYC90LA045  1990-01-03
# ...           ...             ...       ...             ...         ...
# 49748       82243  20221227106491  Accident      ERA23LA093  2022-12-26
# 49749       82244  20221227106494  Accident      ERA23LA095  2022-12-26
# 49750       82245  20221227106497  Accident      WPR23LA075  2022-12-26
# 49751       82246  20221227106498  Accident      WPR23LA076  2022-12-26
# 49752       82247  20221230106513  Accident      ERA23LA097  2022-12-29
#
#                 Location        Country Injury_Severity  Damage_type  \
# ...

# %%
make_counts = df['Make'].value_counts()

# %%
make_counts
# Out:
# Cessna                           12605
# Piper                             6779
# CESSNA                            4227
# PIPER                             2485
# Beech                             2456
#                                  ...
# Allstar Pzl                          1
# Cobb International                   1
# Quad City Ultralight                 1
# Six Chuter, Inc                      1
# AEROSTAR AIRCRAFT CORPORATION        1
# Name: Make, Length: 2006, dtype: int64

# %%
pd.set_option('display.max_rows', df['Make'].nunique())

# %%
make_counts
# Out:
# Cessna                            12605
# Piper                              6779
# CESSNA                             4227
# PIPER                              2485
# Beech                              2456
# Bell                               1134
# BEECH                               874
# Robinson                            695
# Mooney                              654
# Grumman                             522
# Air Tractor                         484
# Boeing                              482
# Bellanca                            471
# Hughes                              444
# Schweizer                           403
# BELL                                390
# Maule                               295
# Aeronca                             285
# Champion                            260
# BOEING                              236
# ROBINSON HELICOPTER                 218
# MOONEY                              216
# AIR TRACTOR INC                     214
# ...

# %%
df['Make'] = df['Make'].str.lower()
df.loc[df['Make'].str.contains('cessna', na=False), 'Make'] = 'Cessna'
make_counts = df['Make'].value_counts()

# %%
make_counts
# Out:
# Cessna                            16867
# piper                              9264
# beech                              3330
# bell                               1524
# mooney                              870
# robinson                            766
# boeing                              718
# bellanca                            628
# grumman                             587
# hughes                              558
# air tractor                         538
# schweizer                           538
# aeronca                             433
# maule                               432
# champion                            347
# stinson                             303
# luscombe                            299
# north american                      263
# taylorcraft                         254
# aero commander                      252
# de havilland                        230
# robinson helicopter                 227
# mcdonnell douglas                   224
# ...

# %%
df['Make'].value_counts()
# Out:
# Cessna                            16867
# piper                              9264
# beech                              3330
# bell                               1524
# mooney                              870
# robinson                            766
# boeing                              718
# bellanca                            628
# grumman                             587
# hughes                              558
# air tractor                         538
# schweizer                           538
# aeronca                             433
# maule                               432
# champion                            347
# stinson                             303
# luscombe                            299
# north american                      263
# taylorcraft                         254
# aero commander                      252
# de havilland                        230
# robinson helicopter                 227
# mcdonnell douglas                   224
# ...

# %%
df.loc[df['Make'].str.contains('beechcraft', na=False), 'Make'] = 'Beechcraft'

# %%
df['Make'].value_counts()
# Out:
# Cessna                            16867
# piper                              9264
# beech                              3330
# bell                               1524
# mooney                              870
# robinson                            766
# boeing                              718
# bellanca                            628
# grumman                             587
# hughes                              558
# schweizer                           538
# air tractor                         538
# aeronca                             433
# maule                               432
# champion                            347
# stinson                             303
# luscombe                            299
# north american                      263
# taylorcraft                         254
# aero commander                      252
# de havilland                        230
# robinson helicopter                 227
# mcdonnell douglas                   224
# ...

# %%
df.loc[df['Make'].str.contains('boeing', na=False), 'Make'] = 'Boeing'

# %%
df['Make'].value_counts()
# Out:
# Cessna                            16867
# piper                              9264
# beech                              3330
# bell                               1524
# mooney                              870
# Boeing                              775
# robinson                            766
# bellanca                            628
# grumman                             587
# hughes                              558
# schweizer                           538
# air tractor                         538
# aeronca                             433
# maule                               432
# champion                            347
# stinson                             303
# luscombe                            299
# north american                      263
# taylorcraft                         254
# aero commander                      252
# de havilland                        230
# robinson helicopter                 227
# mcdonnell douglas                   224
# ...

# %%
df.loc[df['Make'].str.contains('bellanca', na=False), 'Make'] = 'Bellanca'

# %%
df['Make'].value_counts()
# Out:
# Cessna                            16867
# piper                              9264
# beech                              3330
# bell                               1524
# mooney                              870
# Boeing                              775
# robinson                            766
# Bellanca                            630
# grumman                             587
# hughes                              558
# air tractor                         538
# schweizer                           538
# aeronca                             433
# maule                               432
# champion                            347
# stinson                             303
# luscombe                            299
# north american                      263
# taylorcraft                         254
# aero commander                      252
# de havilland                        230
# robinson helicopter                 227
# mcdonnell douglas                   224
# ...
